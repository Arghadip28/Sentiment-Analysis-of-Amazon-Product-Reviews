# %% [markdown]
# # **Imports**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import download
from wordcloud import WordCloud

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # **Load Data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Colab Notebooks/amazon'
data_path = '/content/drive/MyDrive/Colab Notebooks/amazon/FshionProductReviews_V3.csv'

# %%
data = pd.read_csv(data_path)
data.head(10)
# Out:
#    overall  verified  reviewTime  \
# 0        2      True  2014-09-28
# 1        2      True  2014-08-24
# 2        4      True  2014-05-31
# 3        3      True  2013-09-22
# 4        3      True  2013-07-17
# 5        4      True  2013-03-09
# 6        2      True  2013-01-27
# 7        1      True  2013-01-04
# 8        1      True  2012-07-30
# 9        3      True  2017-10-31
#
#                                           reviewText  \
# 0  I agree with the other review, the opening is ...
# 1                                too tiny an opening
# 2  These little plastic backs work great.  No mor...
# 3  mother - in - law wanted it as a present for h...
# 4  Item is of good quality. Looks great, too. But...
# 5  This brand has been around a long time and you...
# 6  I smoke 100's and these are NOT made for them....
# 7  cheap and cheesy, but i guess i could have exp...
# 8  I ordered a ladies cigarette case for my wife,...
# 9  Love it but it tore up shortly after I got it....
#
#                                              summary  length
# 0  I agree with the other review, the opening is ...      48
# 1                                          Two Stars       4
# 2                                       Works great!      28
# 3                                bought as a present      21
# 4                          Buxton heiress collection      68
# 5                                    BUXTON QUALITY!      26
# 6  Buxton Heiress Collection Black Leather Cigare...      26
# 7                                   inexpensive case      20
# 8                               i was ripped off!!!!      58
# 9     Love it but it tore up shortly after I got ...      31

# %%
data.shape
# Out:
# (658184, 6)

# %% [markdown]
# # **Text Cleaning**

# %%
# converting to lower case
data['reviewText'] = data.reviewText.str.lower()
data.reviewText
# Out:
# 0         i agree with the other review, the opening is ...
# 1                                       too tiny an opening
# 2         these little plastic backs work great.  no mor...
# 3         mother - in - law wanted it as a present for h...
# 4         item is of good quality. looks great, too. but...
#                                 ...
# 658179    i absolutely love this dress!!  it's sexy and ...
# 658180    i'm 5'6 175lbs. i'm on the tall side. i wear a...
# 658181                           too big in the chest area!
# 658182                  too clear in the back, needs lining
# 658183    ordered and was slightly small. worked with th...
# Name: reviewText, Length: 658184, dtype: object

# %%
# Removing Punctuation
data['reviewText'] = data.reviewText.str.replace('[^\w\s]','')
data.reviewText
# Out:
# <ipython-input-42-e374a3fb5b0e>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['reviewText'] = data.reviewText.str.replace('[^\w\s]','')
# 0         i agree with the other review the opening is t...
# 1                                       too tiny an opening
# 2         these little plastic backs work great  no more...
# 3         mother  in  law wanted it as a present for her...
# 4         item is of good quality looks great too but it...
#                                 ...
# 658179    i absolutely love this dress  its sexy and com...
# 658180    im 56 175lbs im on the tall side i wear a larg...
# 658181                            too big in the chest area
# 658182                   too clear in the back needs lining
# 658183    ordered and was slightly small worked with the...
# Name: reviewText, Length: 658184, dtype: object

# %%
# REmoving non character
data['reviewText'] = data.reviewText.str.replace('\d+','')
data.reviewText
# Out:
# <ipython-input-43-bcd87efbb0db>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['reviewText'] = data.reviewText.str.replace('\d+','')
# 0         i agree with the other review the opening is t...
# 1                                       too tiny an opening
# 2         these little plastic backs work great  no more...
# 3         mother  in  law wanted it as a present for her...
# 4         item is of good quality looks great too but it...
#                                 ...
# 658179    i absolutely love this dress  its sexy and com...
# 658180    im  lbs im on the tall side i wear a large and...
# 658181                            too big in the chest area
# 658182                   too clear in the back needs lining
# 658183    ordered and was slightly small worked with the...
# Name: reviewText, Length: 658184, dtype: object

# %%
# Removing Emojis
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags 
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
data['reviewText'] = data.reviewText.apply(lambda text: remove_emoji(str(text)))
data[['reviewText',]]
# Out:
#                                                reviewText
# 0       i agree with the other review the opening is t...
# 1                                     too tiny an opening
# 2       these little plastic backs work great  no more...
# 3       mother  in  law wanted it as a present for her...
# 4       item is of good quality looks great too but it...
# ...                                                   ...
# 658179  i absolutely love this dress  its sexy and com...
# 658180  im  lbs im on the tall side i wear a large and...
# 658181                          too big in the chest area
# 658182                 too clear in the back needs lining
# 658183  ordered and was slightly small worked with the...
#
# [658184 rows x 1 columns]

# %%
print(u"\U0001F600")
# Out:
# 😀

# %%
# Stopwords list
stop_words = set(stopwords.words('english'))
stop_words.update([
    "br","href", "http", "www"
])

# %%
textt = " ".join(review for review in data.reviewText)
wordcloud = WordCloud(stopwords=stop_words).generate(textt)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# update requent words for fashion data
stop_words.update([
  "ordered", 'bought', 'dress', 'order', 'color', 'shirt', 'one', 'tshirt', 'product',
  'item', 'would', 'could', 'make', 'fabric', 'jeans', 'sweater', 'jacket', 'pant', 'shoe', 'trouser', 
  'clothing', 'apparel', 'fashion''style', 'brand', 'collection', 'designer','season','trend','outfit',
  'accessory','runway','model','fabric','garment','store','shop','boutique','retail','customer','color'
  'size','material','design','look','dress','skirt','blouse','coat', 'accessory','jewelry','handbag','hat','scarf','sunglasses',
  'watch','makeup','hair','model','photography','influencer','marketing','promotion','sale','discount','price', 'wear', 'picture',
  'received', 'money', 'actually', 'almost', 'also', 'another',
       'arm', 'around', 'arrived', 'baby', 'back','bag', 'band', 'belt', 'bit', 'black', 'boot', 'bottom', 'came',
       'cant', 'come', 'costume', 'cover', 'cut', 'daughter', 'day', 'different', 'easy', 'enough', 'er', 'even',  'extra', 'find'
       'first', 'foot', 'gave', 'get', 'gift', 'give', 'glass',
       'go', 'going', 'got', 'head', 'however', 'husband', 'im', 'ive', 'keep', 'know', 'made', 'make', 'many', 'month',
       'overall', 'pair', 'pant', 'part', 'piece',
       'pocket', 'purchase', 'purchased', 'purse','put', 'review', 'ring', 'run', 'said', 'say', 'see', 'seems',
       'shipping', 'shoe', 'short', 'side', 'since', 'sleeve', 'sock', 'something', 'son', 'stay', 'still', 'strap', 'sun',
       'support', 'theyre', 'thing', 'time', 'took', 'tried', 'true', 'two', 'use', 'usually', 'wash',
       'way', 'week', 'white', 'without', 'woman', 'worn', 'xl', 'year'
])

# %%
wordcloud = WordCloud(stopwords=stop_words).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Natural Language Processing

# %%
data.head(10)
# Out:
#    overall  verified  reviewTime  \
# 0        2      True  2014-09-28
# 1        2      True  2014-08-24
# 2        4      True  2014-05-31
# 3        3      True  2013-09-22
# 4        3      True  2013-07-17
# 5        4      True  2013-03-09
# 6        2      True  2013-01-27
# 7        1      True  2013-01-04
# 8        1      True  2012-07-30
# 9        3      True  2017-10-31
#
#                                           reviewText  \
# 0  i agree with the other review the opening is t...
# 1                                too tiny an opening
# 2  these little plastic backs work great  no more...
# 3  mother  in  law wanted it as a present for her...
# 4  item is of good quality looks great too but it...
# 5  this brand has been around a long time and you...
# 6  i smoke s and these are not made for them  i c...
# 7  cheap and cheesy but i guess i could have expe...
# 8  i ordered a ladies cigarette case for my wife ...
# 9  love it but it tore up shortly after i got it ...
#
#                                              summary  length
# 0  I agree with the other review, the opening is ...      48
# 1                                          Two Stars       4
# 2                                       Works great!      28
# 3                                bought as a present      21
# 4                          Buxton heiress collection      68
# 5                                    BUXTON QUALITY!      26
# 6  Buxton Heiress Collection Black Leather Cigare...      26
# 7                                   inexpensive case      20
# 8                               i was ripped off!!!!      58
# 9     Love it but it tore up shortly after I got ...      31

# %%
data[data.overall == 3]
# Out:
#         overall  verified  reviewTime  \
# 3             3      True  2013-09-22
# 4             3      True  2013-07-17
# 9             3      True  2017-10-31
# 11            3      True  2017-10-07
# 20            3      True  2017-04-26
# ...         ...       ...         ...
# 658162        3      True  2017-03-17
# 658164        3      True  2017-01-09
# 658165        3      True  2016-11-29
# 658181        3      True  2016-11-10
# 658182        3      True  2016-11-10
#
#                                                reviewText  \
# 3       mother  in  law wanted it as a present for her...
# 4       item is of good quality looks great too but it...
# 9       love it but it tore up shortly after i got it ...
# 11      it is smaller than what i was expecting the zi...
# 20                                nice but does not fit s
# ...                                                   ...
# 658162  small fit and a bit short but im  so everythin...
# 658164  really cute dress i bought a small and medium ...
# 658165  ordered an xl\nfits like a m\nthe fabric is ad...
# 658181                          too big in the chest area
# 658182                 too clear in the back needs lining
#
#                                                   summary  length
# 3                                     bought as a present      21
# 4                               Buxton heiress collection      68
# 9          Love it but it tore up shortly after I got ...      31
# 11                                            Three Stars      16
# 20                                            Three Stars       6
# ...                                                   ...     ...
# 658162                                        Three Stars      18
# 658164  Really cute dress. I bought a small and medium...      60
# 658165                                    Runs very small      10
# 658181                                        Three Stars       6
# 658182                                        Three Stars       7
#
# [75993 rows x 6 columns]

# %%
# Add dummy sentiment column
data['sentiment'] = 0
data
# Out:
#         overall  verified  reviewTime  \
# 0             2      True  2014-09-28
# 1             2      True  2014-08-24
# 2             4      True  2014-05-31
# 3             3      True  2013-09-22
# 4             3      True  2013-07-17
# ...         ...       ...         ...
# 658179        5      True  2017-02-21
# 658180        5      True  2016-11-25
# 658181        3      True  2016-11-10
# 658182        3      True  2016-11-10
# 658183        5      True  2016-08-09
#
#                                                reviewText  \
# 0       i agree with the other review the opening is t...
# 1                                     too tiny an opening
# 2       these little plastic backs work great  no more...
# 3       mother  in  law wanted it as a present for her...
# 4       item is of good quality looks great too but it...
# ...                                                   ...
# 658179  i absolutely love this dress  its sexy and com...
# 658180  im  lbs im on the tall side i wear a large and...
# 658181                          too big in the chest area
# 658182                 too clear in the back needs lining
# 658183  ordered and was slightly small worked with the...
#
#                                                   summary  length  sentiment
# 0       I agree with the other review, the opening is ...      48          0
# 1                                               Two Stars       4          0
# 2                                            Works great!      28          0
# 3                                     bought as a present      21          0
# 4                               Buxton heiress collection      68          0
# ...                                                   ...     ...        ...
# 658179                       I absolutely love this dress      48          0
# 658180  I wear a large and ordered a large and it stil...      37          0
# 658181                                        Three Stars       6          0
# 658182                                        Three Stars       7          0
# 658183         The quality is excellent and it is so cute      30          0
#
# [658184 rows x 7 columns]

# %%
# Converting rating to Sentiment
data['sentiment'][data.overall > 3] = 1
data
# Out:
# <ipython-input-54-e5b4ee1d8a87>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sentiment'][data.overall > 3] = 1
#         overall  verified  reviewTime  \
# 0             2      True  2014-09-28
# 1             2      True  2014-08-24
# 2             4      True  2014-05-31
# 3             3      True  2013-09-22
# 4             3      True  2013-07-17
# ...         ...       ...         ...
# 658179        5      True  2017-02-21
# 658180        5      True  2016-11-25
# 658181        3      True  2016-11-10
# 658182        3      True  2016-11-10
# 658183        5      True  2016-08-09
#
#                                                reviewText  \
# 0       i agree with the other review the opening is t...
# 1                                     too tiny an opening
# 2       these little plastic backs work great  no more...
# 3       mother  in  law wanted it as a present for her...
# 4       item is of good quality looks great too but it...
# ...                                                   ...
# 658179  i absolutely love this dress  its sexy and com...
# 658180  im  lbs im on the tall side i wear a large and...
# 658181                          too big in the chest area
# 658182                 too clear in the back needs lining
# 658183  ordered and was slightly small worked with the...
#
#                                                   summary  length  sentiment
# 0       I agree with the other review, the opening is ...      48          0
# 1                                               Two Stars       4          0
# 2                                            Works great!      28          1
# 3                                     bought as a present      21          0
# 4                               Buxton heiress collection      68          0
# ...                                                   ...     ...        ...
# 658179                       I absolutely love this dress      48          1
# 658180  I wear a large and ordered a large and it stil...      37          1
# 658181                                        Three Stars       6          0
# 658182                                        Three Stars       7          0
# 658183         The quality is excellent and it is so cute      30          1
#
# [658184 rows x 7 columns]

# %%
download('punkt')
download('stopwords')
download('wordnet')
download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Tokenization
data.reviewText = data.reviewText.apply(
    lambda sentence: word_tokenize(str(sentence))
)
data.head()
# Out:
#    overall  verified  reviewTime  \
# 0        2      True  2014-09-28
# 1        2      True  2014-08-24
# 2        4      True  2014-05-31
# 3        3      True  2013-09-22
# 4        3      True  2013-07-17
#
#                                           reviewText  \
# 0  [i, agree, with, the, other, review, the, open...
# 1                           [too, tiny, an, opening]
# 2  [these, little, plastic, backs, work, great, n...
# 3  [mother, in, law, wanted, it, as, a, present, ...
# 4  [item, is, of, good, quality, looks, great, to...
#
#                                              summary  length  sentiment
# 0  I agree with the other review, the opening is ...      48          0
# 1                                          Two Stars       4          0
# 2                                       Works great!      28          1
# 3                                bought as a present      21          0
# 4                          Buxton heiress collection      68          0

# %%
data.head()['reviewText'][0]
# Out:
# ['i',
#  'agree',
#  'with',
#  'the',
#  'other',
#  'review',
#  'the',
#  'opening',
#  'is',
#  'too',
#  'small',
#  'i',
#  'almost',
#  'bent',
#  'the',
#  'hook',
#  'on',
#  'some',
#  'very',
#  'expensive',
#  'earrings',
#  'trying',
#  'to',
#  'get',
#  'these',
#  'up',
#  'higher',
#  'than',
#  'just',
#  'the',
#  'end',
#  'so',
#  'theyre',
#  'not',
#  'seen',
#  'would',
#  'not',
#  'buy',
#  'again',
#  'but',
#  'for',
#  'the',
#  'price',
#  'not',
#  'sending',
#  'back']

# %%
# Remove Stop Words

data['reviewText'] = data.reviewText.apply(
    lambda tokens: [token for token in tokens if token.casefold() not in stop_words]
)

# %%
data.head()
# Out:
#    overall  verified  reviewTime  \
# 0        2      True  2014-09-28
# 1        2      True  2014-08-24
# 2        4      True  2014-05-31
# 3        3      True  2013-09-22
# 4        3      True  2013-07-17
#
#                                           reviewText  \
# 0  [agree, opening, small, bent, hook, expensive,...
# 1                                    [tiny, opening]
# 2  [little, plastic, backs, work, great, loosing,...
# 3  [mother, law, wanted, present, sister, liked, ...
# 4  [good, quality, looks, great, fit, stretched, ...
#
#                                              summary  length  sentiment
# 0  I agree with the other review, the opening is ...      48          0
# 1                                          Two Stars       4          0
# 2                                       Works great!      28          1
# 3                                bought as a present      21          0
# 4                          Buxton heiress collection      68          0

# %%
data.head()['reviewText'][0]
# Out:
# ['agree',
#  'opening',
#  'small',
#  'bent',
#  'hook',
#  'expensive',
#  'earrings',
#  'trying',
#  'higher',
#  'end',
#  'seen',
#  'buy',
#  'sending']

# %%
# Lemmatization to compact in 

lemmatizer = WordNetLemmatizer()
data['reviewText'] = data.reviewText.apply(
    lambda tokens: [lemmatizer.lemmatize(token) for token in tokens]
)

# %%
data.head()
# Out:
#    overall  verified  reviewTime  \
# 0        2      True  2014-09-28
# 1        2      True  2014-08-24
# 2        4      True  2014-05-31
# 3        3      True  2013-09-22
# 4        3      True  2013-07-17
#
#                                           reviewText  \
# 0  [agree, opening, small, bent, hook, expensive,...
# 1                                    [tiny, opening]
# 2  [little, plastic, back, work, great, loosing, ...
# 3  [mother, law, wanted, present, sister, liked, ...
# 4  [good, quality, look, great, fit, stretched, f...
#
#                                              summary  length  sentiment
# 0  I agree with the other review, the opening is ...      48          0
# 1                                          Two Stars       4          0
# 2                                       Works great!      28          1
# 3                                bought as a present      21          0
# 4                          Buxton heiress collection      68          0

# %%
data.head()['reviewText'][0]
# Out:
# ['agree',
#  'opening',
#  'small',
#  'bent',
#  'hook',
#  'expensive',
#  'earring',
#  'trying',
#  'higher',
#  'end',
#  'seen',
#  'buy',
#  'sending']

# %%
# join tokens
data['reviewText'] = data.reviewText.apply(
    lambda tokens: ' '.join(tokens)
)

# %%
data.head()
# Out:
#    overall  verified  reviewTime  \
# 0        2      True  2014-09-28
# 1        2      True  2014-08-24
# 2        4      True  2014-05-31
# 3        3      True  2013-09-22
# 4        3      True  2013-07-17
#
#                                           reviewText  \
# 0  agree opening small bent hook expensive earrin...
# 1                                       tiny opening
# 2  little plastic back work great loosing hook ea...
# 3        mother law wanted present sister liked work
# 4  good quality look great fit stretched fit care...
#
#                                              summary  length  sentiment
# 0  I agree with the other review, the opening is ...      48          0
# 1                                          Two Stars       4          0
# 2                                       Works great!      28          1
# 3                                bought as a present      21          0
# 4                          Buxton heiress collection      68          0

# %%
data.sentiment.value_counts()
# Out:
# 1    445028
# 0    213156
# Name: sentiment, dtype: int64

# %% [markdown]
# # Exploring wordcloud for each sentiment

# %%
# WordCloud for Negetive Sentiment
textt = " ".join(review for review in data.loc[data['sentiment']==0, 'reviewText'])
wordcloud = WordCloud(stopwords=stop_words).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# remove positive words from Negetive Sentiment
def remove_positive_words(row: str) -> str:
  return str(row).replace('great', '').replace('good', '').replace('pretty', '').replace('beautiful', '')\
  .replace('comfortable', '').replace('love', '').replace('better', '').replace('nice', '').replace('fit', '')\
  .replace('also', '').replace('quality', '').replace('cute', '').replace('way', '').replace('top', '').\
  replace('well', '').replace('like', '').replace('expected', '').replace('perfect', '').replace('happy', '')

data.loc[data['sentiment']==0, 'reviewText'] = data.loc[data['sentiment']==0, 'reviewText'].apply(
    remove_positive_words
)

# %%
data.loc[data['sentiment']==0, 'reviewText']
# Out:
# 0         agree opening small bent hook expensive earrin...
# 1                                              tiny opening
# 3                   mother law wanted present sister d work
# 4           look   stretched  carefully push case finger...
# 6                   smoke cigarette wont close disappointed
#                                 ...
# 658164    really  small medium return didnt close front ...
# 658165                                      adorable though
# 658171                                                sheer
# 658181                                       big chest area
# 658182                                    clear need lining
# Name: reviewText, Length: 213156, dtype: object

# %%
textt = " ".join(review for review in data[data['sentiment']==0]['reviewText'])
wordcloud = WordCloud(stopwords=stop_words).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# WordCloud for Positive Sentiment
textt = " ".join(review for review in data[data['sentiment']==1]['reviewText'])
wordcloud = WordCloud(stopwords=stop_words).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
data.loc[data['sentiment']==1, 'reviewText']
# Out:
# 2         little plastic back work great loosing hook ea...
# 5         long count good quality merchandise held well ...
# 10                                       love looking thank
# 13        wonderful several last forever unless lose hap...
# 14        love think six seven case buxton stylish durab...
#                                 ...
# 658177    beautifull person photo lb bougth size l big s...
# 658178                   love love love iam large beautiful
# 658179    absolutely love sexy comfortable split much se...
# 658180    lb tall large large comfortable amount room sn...
# 658183    slightly small worked company graciously sendi...
# Name: reviewText, Length: 445028, dtype: object

# %%
# remove unnecessary negetive words from Positive Sentiment
def remove_negetive_words(row: str) -> str:
  return row.replace('bad', '').replace('used', '').replace('however', '').replace('old', '')\
  .replace('problem', '').replace('made', '').replace('necklace', '').replace('short', '')\
  .replace('small', '').replace('looking', '').replace('poor', '')


data.loc[data['sentiment']==1, 'reviewText'] = data.loc[data['sentiment']==1, 'reviewText'].apply(
    remove_negetive_words
)

# %%
data.loc[data['sentiment']==1, 'reviewText']
# Out:
# 2         little plastic back work great loosing hook ea...
# 5         long count good quality merchandise held well ...
# 10                                              love  thank
# 13        wonderful several last forever unless lose hap...
# 14        love think six seven case buxton stylish durab...
#                                 ...
# 658177    beautifull person photo lb bougth size l big s...
# 658178                   love love love iam large beautiful
# 658179    absolutely love sexy comfortable split much se...
# 658180    lb tall large large comfortable amount room sn...
# 658183    slightly  worked company graciously sending bi...
# Name: reviewText, Length: 445028, dtype: object

# %%
textt = " ".join(review for review in data.loc[data['sentiment']==1, 'reviewText'])
wordcloud = WordCloud(stopwords=stop_words).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
data
# Out:
#         overall  verified  reviewTime  \
# 0             2      True  2014-09-28
# 1             2      True  2014-08-24
# 2             4      True  2014-05-31
# 3             3      True  2013-09-22
# 4             3      True  2013-07-17
# ...         ...       ...         ...
# 658179        5      True  2017-02-21
# 658180        5      True  2016-11-25
# 658181        3      True  2016-11-10
# 658182        3      True  2016-11-10
# 658183        5      True  2016-08-09
#
#                                                reviewText  \
# 0       agree opening small bent hook expensive earrin...
# 1                                            tiny opening
# 2       little plastic back work great loosing hook ea...
# 3                 mother law wanted present sister d work
# 4         look   stretched  carefully push case finger...
# ...                                                   ...
# 658179  absolutely love sexy comfortable split much se...
# 658180  lb tall large large comfortable amount room sn...
# 658181                                     big chest area
# 658182                                  clear need lining
# 658183  slightly  worked company graciously sending bi...
#
#                                                   summary  length  sentiment
# 0       I agree with the other review, the opening is ...      48          0
# 1                                               Two Stars       4          0
# 2                                            Works great!      28          1
# 3                                     bought as a present      21          0
# 4                               Buxton heiress collection      68          0
# ...                                                   ...     ...        ...
# 658179                       I absolutely love this dress      48          1
# 658180  I wear a large and ordered a large and it stil...      37          1
# 658181                                        Three Stars       6          0
# 658182                                        Three Stars       7          0
# 658183         The quality is excellent and it is so cute      30          1
#
# [658184 rows x 7 columns]

# %% [markdown]
# # Save Data

# %%
data.head()['reviewText'][0]
# Out:
# 'agree opening small bent hook expensive earring trying higher end seen buy sending'

# %%
data.to_csv(
    '/content/drive/MyDrive/Colab Notebooks/amazon/FshionProductReviews_V5_NLP.csv', index=False
)
